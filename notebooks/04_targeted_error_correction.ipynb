# %%
from __future__ import print_function, division

import torch
import torch.optim as optim

from torch.optim import lr_scheduler
from torchvision import datasets, transforms
import time
import os

import torch.nn as nn

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.network = nn.Sequential(
            nn.Flatten(),
            
            # Layer 1: 2048 Neurons
            nn.Linear(32 * 32 * 1, 2048),
            nn.BatchNorm1d(2048),
            nn.ReLU(),
            nn.Dropout(0.3),
            
            # Layer 2: 1024 Neurons
            nn.Linear(2048, 1024),
            nn.BatchNorm1d(1024),
            nn.ReLU(),
            nn.Dropout(0.2),
            
            # Layer 3: 512 Neurons
            nn.Linear(1024, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),
            
            # Output Layer
            nn.Linear(512, 10)
        )
        
    def forward(self, xb):
        return self.network(xb)

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.Grayscale(num_output_channels=1),  
        transforms.RandomRotation(10),
        transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),
        transforms.Resize((32,32)),
        transforms.ToTensor(),
        transforms.Normalize([0.5], [0.5])
    ]),
    'test': transforms.Compose([
        transforms.Grayscale(num_output_channels=1),
        transforms.Resize((32,32)),
        transforms.ToTensor(),
        transforms.Normalize([0.5], [0.5]),
    ]),
}

# %%
def train_test(model, criterion, optimizer, scheduler, num_epochs):
    train_loss = []
    train_accuracy = []
    history = dict()
    model.train()
    
    total_start_time = time.time() 

    for epoch in range(num_epochs):
        running_training_loss = 0.0
        running_training_accuracy = 0.0
        total_training_predictions = 0
       
        start_time = time.time()
        for i, data in enumerate(train_dataloader, 0):
            inputs, labels = data[0].to(device), data[1].to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            running_training_loss += loss.item()*inputs.size(0)
            _, predicted = torch.max(outputs.data, 1)
            total_training_predictions += labels.size(0)
            running_training_accuracy += (predicted == labels).sum().item()

        end_time = time.time()
        epoch_training_accuracy = running_training_accuracy / train_size*100
        epoch_training_loss = running_training_loss / train_size
        
        print(f'Epoch:[{epoch + 1}], Accuracy: {epoch_training_accuracy:.1f}%, Loss: {epoch_training_loss:.3f}, Time: {end_time-start_time:.1f}s')
        
        train_loss.append(epoch_training_loss)
        train_accuracy.append(epoch_training_accuracy)
        scheduler.step()
        
    print('Finished Training')

    # --- PER-CLASS ACCURACY SECTION ---
    correct_pred = {str(i): 0 for i in range(10)}
    total_pred = {str(i): 0 for i in range(10)}

    model.eval()
    with torch.no_grad():
        for data in test_dataloader:
            images, labels = data[0].to(device), data[1].to(device)
            outputs = model(images)
            _, predictions = torch.max(outputs, 1)
            for label, prediction in zip(labels, predictions):
                if label == prediction:
                    correct_pred[str(label.item())] += 1
                total_pred[str(label.item())] += 1

    print('\nAccuracy per class:')
    for classname, correct_count in correct_pred.items():
        accuracy = 100 * float(correct_count) / total_pred[classname]
        print(f'Class {classname:5s}: {accuracy:.1f} %')

    overall_accuracy = 100 * sum(correct_pred.values()) / sum(total_pred.values())
    total_duration = time.time() - total_start_time
    print(f'\nOverall Test Accuracy: {overall_accuracy:.1f} %')
    print(f'Total Program Time: {total_duration/60:.2f} minutes') 
    
    return history, overall_accuracy

# %%
if __name__ == '__main__':
    data_dir = './data'    
    image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                            data_transforms[x])
                    for x in ['train', 'test']}

    train_dataloader = torch.utils.data.DataLoader(image_datasets['train'], batch_size=128,
                                                shuffle=True, num_workers=4)

    test_dataloader = torch.utils.data.DataLoader(image_datasets['test'], batch_size=128,
                                                shuffle=False, num_workers=4)

    train_size = len(image_datasets['train'])
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    model_ft = Net().to(device)
    weights = torch.tensor([1.0, 1.0, 1.0, 2.0, 1.0, 1.2, 1.2, 1.0, 1.0, 1.0]).to(device)
    criterion = nn.CrossEntropyLoss(weight=weights)

    optimizer_ft = optim.Adam(model_ft.parameters(), lr=0.0005)  

    exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=20, gamma=0.7)
    
    history, accuracy = train_test(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
               num_epochs=80)
# Out:
# Epoch:[1], Accuracy: 23.3%, Loss: 2.058, Time: 22.4s
# Epoch:[2], Accuracy: 45.7%, Loss: 1.565, Time: 21.9s
# Epoch:[3], Accuracy: 54.1%, Loss: 1.362, Time: 21.9s
# Epoch:[4], Accuracy: 59.4%, Loss: 1.220, Time: 21.7s
# Epoch:[5], Accuracy: 62.2%, Loss: 1.140, Time: 21.9s
# Epoch:[6], Accuracy: 64.3%, Loss: 1.084, Time: 21.7s
# Epoch:[7], Accuracy: 66.2%, Loss: 1.029, Time: 21.9s
# Epoch:[8], Accuracy: 67.5%, Loss: 0.994, Time: 21.9s
# Epoch:[9], Accuracy: 68.7%, Loss: 0.960, Time: 22.1s
# Epoch:[10], Accuracy: 69.6%, Loss: 0.933, Time: 21.8s
# Epoch:[11], Accuracy: 70.4%, Loss: 0.908, Time: 21.7s
# Epoch:[12], Accuracy: 71.5%, Loss: 0.884, Time: 21.9s
# Epoch:[13], Accuracy: 71.6%, Loss: 0.876, Time: 21.8s
# Epoch:[14], Accuracy: 72.4%, Loss: 0.856, Time: 21.9s
# Epoch:[15], Accuracy: 73.2%, Loss: 0.835, Time: 21.6s
# Epoch:[16], Accuracy: 73.3%, Loss: 0.822, Time: 21.9s
# Epoch:[17], Accuracy: 74.0%, Loss: 0.806, Time: 22.1s
# Epoch:[18], Accuracy: 74.1%, Loss: 0.801, Time: 21.7s
# Epoch:[19], Accuracy: 74.5%, Loss: 0.791, Time: 21.7s
# Epoch:[20], Accuracy: 74.8%, Loss: 0.773, Time: 21.7s
# Epoch:[21], Accuracy: 76.1%, Loss: 0.740, Time: 21.9s
# Epoch:[22], Accuracy: 76.7%, Loss: 0.726, Time: 21.8s
# Epoch:[23], Accuracy: 77.0%, Loss: 0.714, Time: 22.1s
# Epoch:[24], Accuracy: 77.1%, Loss: 0.699, Time: 21.7s
# Epoch:[25], Accuracy: 78.0%, Loss: 0.689, Time: 21.8s
# Epoch:[26], Accuracy: 77.9%, Loss: 0.687, Time: 22.1s
# Epoch:[27], Accuracy: 77.7%, Loss: 0.688, Time: 21.8s
# Epoch:[28], Accuracy: 78.3%, Loss: 0.676, Time: 21.7s
# Epoch:[29], Accuracy: 78.3%, Loss: 0.668, Time: 21.8s
# Epoch:[30], Accuracy: 78.5%, Loss: 0.666, Time: 22.0s
# Epoch:[31], Accuracy: 78.7%, Loss: 0.657, Time: 22.0s
# Epoch:[32], Accuracy: 79.0%, Loss: 0.653, Time: 21.7s
# Epoch:[33], Accuracy: 79.4%, Loss: 0.643, Time: 22.0s
# Epoch:[34], Accuracy: 79.0%, Loss: 0.641, Time: 22.0s
# Epoch:[35], Accuracy: 79.7%, Loss: 0.636, Time: 21.9s
# Epoch:[36], Accuracy: 79.5%, Loss: 0.631, Time: 22.0s
# Epoch:[37], Accuracy: 79.8%, Loss: 0.625, Time: 21.9s
# Epoch:[38], Accuracy: 79.8%, Loss: 0.622, Time: 21.9s
# Epoch:[39], Accuracy: 80.2%, Loss: 0.610, Time: 22.8s
# Epoch:[40], Accuracy: 80.2%, Loss: 0.611, Time: 26.4s
# Epoch:[41], Accuracy: 81.3%, Loss: 0.585, Time: 22.4s
# Epoch:[42], Accuracy: 81.3%, Loss: 0.575, Time: 22.3s
# Epoch:[43], Accuracy: 81.5%, Loss: 0.569, Time: 21.8s
# Epoch:[44], Accuracy: 81.7%, Loss: 0.567, Time: 21.9s
# Epoch:[45], Accuracy: 81.9%, Loss: 0.564, Time: 21.9s
# Epoch:[46], Accuracy: 81.7%, Loss: 0.559, Time: 21.9s
# Epoch:[47], Accuracy: 81.9%, Loss: 0.558, Time: 21.9s
# Epoch:[48], Accuracy: 82.2%, Loss: 0.549, Time: 21.8s
# Epoch:[49], Accuracy: 82.2%, Loss: 0.547, Time: 21.8s
# Epoch:[50], Accuracy: 82.8%, Loss: 0.540, Time: 21.7s
# Epoch:[51], Accuracy: 82.5%, Loss: 0.545, Time: 22.1s
# Epoch:[52], Accuracy: 82.8%, Loss: 0.540, Time: 21.8s
# Epoch:[53], Accuracy: 82.7%, Loss: 0.533, Time: 22.1s
# Epoch:[54], Accuracy: 82.9%, Loss: 0.529, Time: 21.9s
# Epoch:[55], Accuracy: 82.8%, Loss: 0.529, Time: 22.0s
# Epoch:[56], Accuracy: 83.0%, Loss: 0.525, Time: 21.8s
# Epoch:[57], Accuracy: 83.4%, Loss: 0.521, Time: 21.8s
# Epoch:[58], Accuracy: 82.8%, Loss: 0.526, Time: 22.1s
# Epoch:[59], Accuracy: 83.0%, Loss: 0.519, Time: 21.9s
# Epoch:[60], Accuracy: 83.6%, Loss: 0.509, Time: 21.8s
# Epoch:[61], Accuracy: 83.7%, Loss: 0.501, Time: 21.8s
# Epoch:[62], Accuracy: 84.3%, Loss: 0.488, Time: 22.2s
# Epoch:[63], Accuracy: 84.3%, Loss: 0.484, Time: 21.8s
# Epoch:[64], Accuracy: 84.0%, Loss: 0.492, Time: 22.0s
# Epoch:[65], Accuracy: 84.3%, Loss: 0.483, Time: 21.9s
# Epoch:[66], Accuracy: 84.3%, Loss: 0.483, Time: 21.8s
# Epoch:[67], Accuracy: 84.6%, Loss: 0.483, Time: 22.0s
# Epoch:[68], Accuracy: 84.6%, Loss: 0.473, Time: 22.1s
# Epoch:[69], Accuracy: 84.6%, Loss: 0.470, Time: 21.9s
# Epoch:[70], Accuracy: 84.9%, Loss: 0.472, Time: 21.8s
# Epoch:[71], Accuracy: 84.7%, Loss: 0.472, Time: 24.4s
# Epoch:[72], Accuracy: 85.0%, Loss: 0.467, Time: 24.6s
# Epoch:[73], Accuracy: 85.1%, Loss: 0.462, Time: 23.5s
# Epoch:[74], Accuracy: 84.7%, Loss: 0.468, Time: 28.0s
# Epoch:[75], Accuracy: 85.3%, Loss: 0.456, Time: 23.4s
# Epoch:[76], Accuracy: 84.8%, Loss: 0.465, Time: 22.8s
# Epoch:[77], Accuracy: 85.4%, Loss: 0.452, Time: 21.8s
# Epoch:[78], Accuracy: 85.1%, Loss: 0.455, Time: 23.8s
# Epoch:[79], Accuracy: 85.4%, Loss: 0.448, Time: 23.6s
# Epoch:[80], Accuracy: 85.3%, Loss: 0.451, Time: 22.9s
# Finished Training
#
# Accuracy per class:
# Class 0    : 87.4 %
# Class 1    : 90.4 %
# Class 2    : 88.6 %
# Class 3    : 86.0 %
# Class 4    : 91.6 %
# Class 5    : 83.8 %
# Class 6    : 83.8 %
# Class 7    : 92.2 %
# Class 8    : 82.8 %
# Class 9    : 85.0 %
#
# Overall Test Accuracy: 87.2 %
# Total Program Time: 29.86 minutes

# %%
import matplotlib.pyplot as plt
import re

def plot_from_log(file_name, exp_name):
    epochs, accs, losses = [], [], []
    
    with open(file_name, 'r') as f:
        content = f.read()
    
    pattern = r"Epoch:?\[(\d+)\],?\s*Accuracy:?\s*([\d.]+)%,?\s*Loss:?\s*([\d.]+)"
    matches = re.findall(pattern, content)
    
    for m in matches:
        epochs.append(int(m[0]))
        accs.append(float(m[1]))
        losses.append(float(m[2]))

    plt.figure(figsize=(12, 5))
    
    plt.subplot(1, 2, 1)
    plt.plot(epochs, accs, label='Training Accuracy', color='#1f77b4', linewidth=2)
    plt.title(f'{exp_name}: Accuracy Curve')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy (%)')
    
    plt.xlim(0, 80)
    plt.ylim(0, 100)
    
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, losses, label='Training Loss', color='#d62728', linewidth=2)
    plt.title(f'{exp_name}: Loss Curve')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    
    plt.xlim(0, 80)
    plt.ylim(0, 2.5) 
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.legend()

    plt.tight_layout()
    plt.savefig(f'{exp_name}_standardized_curves.png', dpi=300) 
    plt.show()

plot_from_log('04_targeted_error_correction_log.txt', '04_targeted_error_correction')
