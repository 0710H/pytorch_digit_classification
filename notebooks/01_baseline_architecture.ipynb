# %%
from __future__ import print_function, division

import torch
import torch.optim as optim

from torch.optim import lr_scheduler
from torchvision import datasets, transforms
import time
import os

import torch.nn as nn

# %%
class Net(nn.Module):

    def __init__(self):
        super().__init__()
        self.network = nn.Sequential(
            nn.Flatten(),  # Converts 32x32 image to 1024 vector
            
            # Layer 1: Wider layer with Batch Normalization
            nn.Linear(32 * 32 * 1, 1024),
            nn.BatchNorm1d(1024), # Stabilizes learning
            nn.ReLU(),
            nn.Dropout(0.4),      # Prevents overfitting
            
            # Layer 2: Transition layer
            nn.Linear(1024, 512),
            nn.BatchNorm1d(512), 
            nn.ReLU(),
            nn.Dropout(0.3),
            
            # Layer 3: Final hidden layer
            nn.Linear(512, 256),
            nn.ReLU(),
            
            # Output Layer: 10 classes for digits 0-9
            nn.Linear(256, 10)
        )
        
    def forward(self, xb):
        return self.network(xb)

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.Grayscale(num_output_channels=1),  
        transforms.RandomRotation(15),
        transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),
        transforms.Resize((32,32)),
        transforms.ToTensor(),
        transforms.Normalize([0.5], [0.5])
    ]),
    'test': transforms.Compose([
        transforms.Grayscale(num_output_channels=1),
        transforms.Resize((32,32)),
        transforms.ToTensor(),
        transforms.Normalize([0.5], [0.5]),
    ]),
}

# %%
def train_test(model, criterion, optimizer, scheduler, num_epochs):
    train_loss = []
    train_accuracy = []
    history = dict()
    model.train()
    
    total_start_time = time.time()

    for epoch in range(num_epochs):
        running_training_loss = 0.0
        running_training_accuracy = 0.0
        total_training_predictions = 0
       
        start_time = time.time()
        for i, data in enumerate(train_dataloader, 0):
            inputs, labels = data[0].to(device), data[1].to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            running_training_loss += loss.item()*inputs.size(0)
            _, predicted = torch.max(outputs.data, 1)
            total_training_predictions += labels.size(0)
            running_training_accuracy += (predicted == labels).sum().item()

        end_time = time.time()
        epoch_training_accuracy = running_training_accuracy / train_size*100
        epoch_training_loss = running_training_loss / train_size
        
        print(f'Epoch:[{epoch + 1}], Accuracy: {epoch_training_accuracy:.1f}%, Loss: {epoch_training_loss:.3f}, Time: {end_time-start_time:.1f}s')
        
        train_loss.append(epoch_training_loss)
        train_accuracy.append(epoch_training_accuracy)
        scheduler.step()
        
    print('Finished Training')

    # --- PER-CLASS ACCURACY SECTION ---
    correct_pred = {str(i): 0 for i in range(10)}
    total_pred = {str(i): 0 for i in range(10)}

    model.eval()
    with torch.no_grad():
        for data in test_dataloader:
            images, labels = data[0].to(device), data[1].to(device)
            outputs = model(images)
            _, predictions = torch.max(outputs, 1)
            for label, prediction in zip(labels, predictions):
                if label == prediction:
                    correct_pred[str(label.item())] += 1
                total_pred[str(label.item())] += 1

    print('\nAccuracy per class:')
    for classname, correct_count in correct_pred.items():
        accuracy = 100 * float(correct_count) / total_pred[classname]
        print(f'Class {classname:5s}: {accuracy:.1f} %')

    overall_accuracy = 100 * sum(correct_pred.values()) / sum(total_pred.values())
    total_duration = time.time() - total_start_time
    print(f'\nOverall Test Accuracy: {overall_accuracy:.1f} %')
    print(f'Total Program Time: {total_duration/60:.2f} minutes') # Check against 45-min limit
    
    return history, overall_accuracy

# %%
if __name__ == '__main__':
    data_dir = './data'    
    
    image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                            data_transforms[x])
                    for x in ['train', 'test']}

    train_dataloader = torch.utils.data.DataLoader(image_datasets['train'], batch_size=128,
                                                shuffle=True, num_workers=4)

    test_dataloader = torch.utils.data.DataLoader(image_datasets['test'], batch_size=128,
                                                shuffle=False, num_workers=4)

    train_size = len(image_datasets['train'])
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    model_ft = Net().to(device)
    criterion = nn.CrossEntropyLoss()

    optimizer_ft = optim.Adam(model_ft.parameters(), lr=0.0005)  

    # Scheduler: Reduces LR if the model stops improving
    exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=10, gamma=0.7)
    
    history, accuracy = train_test(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
               num_epochs=40)
# Out:
# Epoch:[1], Accuracy: 18.9%, Loss: 2.193, Time: 19.5s
# Epoch:[2], Accuracy: 36.4%, Loss: 1.829, Time: 19.9s
# Epoch:[3], Accuracy: 46.0%, Loss: 1.599, Time: 20.5s
# Epoch:[4], Accuracy: 50.9%, Loss: 1.469, Time: 20.6s
# Epoch:[5], Accuracy: 54.5%, Loss: 1.374, Time: 23.9s
# Epoch:[6], Accuracy: 56.3%, Loss: 1.315, Time: 21.0s
# Epoch:[7], Accuracy: 58.6%, Loss: 1.255, Time: 18.8s
# Epoch:[8], Accuracy: 60.3%, Loss: 1.216, Time: 18.7s
# Epoch:[9], Accuracy: 61.8%, Loss: 1.174, Time: 20.4s
# Epoch:[10], Accuracy: 62.3%, Loss: 1.147, Time: 19.9s
# Epoch:[11], Accuracy: 64.5%, Loss: 1.088, Time: 20.4s
# Epoch:[12], Accuracy: 65.4%, Loss: 1.065, Time: 21.5s
# Epoch:[13], Accuracy: 66.5%, Loss: 1.042, Time: 18.7s
# Epoch:[14], Accuracy: 66.5%, Loss: 1.030, Time: 18.5s
# Epoch:[15], Accuracy: 67.0%, Loss: 1.017, Time: 19.9s
# Epoch:[16], Accuracy: 67.3%, Loss: 1.004, Time: 20.6s
# Epoch:[17], Accuracy: 68.2%, Loss: 0.985, Time: 19.2s
# Epoch:[18], Accuracy: 68.5%, Loss: 0.974, Time: 18.9s
# Epoch:[19], Accuracy: 68.7%, Loss: 0.969, Time: 21.3s
# Epoch:[20], Accuracy: 68.8%, Loss: 0.961, Time: 18.9s
# Epoch:[21], Accuracy: 70.0%, Loss: 0.931, Time: 19.4s
# Epoch:[22], Accuracy: 70.1%, Loss: 0.918, Time: 19.9s
# Epoch:[23], Accuracy: 70.8%, Loss: 0.910, Time: 18.9s
# Epoch:[24], Accuracy: 71.3%, Loss: 0.894, Time: 20.2s
# Epoch:[25], Accuracy: 71.4%, Loss: 0.892, Time: 19.5s
# Epoch:[26], Accuracy: 71.3%, Loss: 0.885, Time: 20.3s
# Epoch:[27], Accuracy: 71.8%, Loss: 0.879, Time: 19.7s
# Epoch:[28], Accuracy: 71.3%, Loss: 0.879, Time: 19.4s
# Epoch:[29], Accuracy: 71.8%, Loss: 0.867, Time: 18.9s
# Epoch:[30], Accuracy: 72.3%, Loss: 0.861, Time: 18.2s
# Epoch:[31], Accuracy: 73.2%, Loss: 0.838, Time: 18.3s
# Epoch:[32], Accuracy: 73.5%, Loss: 0.828, Time: 18.3s
# Epoch:[33], Accuracy: 73.2%, Loss: 0.836, Time: 20.3s
# Epoch:[34], Accuracy: 73.1%, Loss: 0.829, Time: 18.3s
# Epoch:[35], Accuracy: 73.6%, Loss: 0.819, Time: 19.3s
# Epoch:[36], Accuracy: 73.7%, Loss: 0.815, Time: 18.6s
# Epoch:[37], Accuracy: 73.9%, Loss: 0.815, Time: 18.9s
# Epoch:[38], Accuracy: 74.3%, Loss: 0.801, Time: 18.6s
# Epoch:[39], Accuracy: 74.3%, Loss: 0.803, Time: 18.6s
# Epoch:[40], Accuracy: 74.4%, Loss: 0.804, Time: 18.7s
# Finished Training
#
# Accuracy per class:
# Class 0    : 88.2 %
# Class 1    : 87.0 %
# Class 2    : 84.0 %
# Class 3    : 75.0 %
# Class 4    : 91.0 %
# Class 5    : 79.8 %
# Class 6    : 81.8 %
# Class 7    : 89.2 %
# Class 8    : 76.8 %
# Class 9    : 80.8 %
#
# Overall Test Accuracy: 83.4 %
# Total Program Time: 13.29 minutes

# %%
import matplotlib.pyplot as plt
import re

def plot_from_log(file_name, exp_name):
    epochs, accs, losses = [], [], []
    
    with open(file_name, 'r') as f:
        content = f.read()
    
    pattern = r"Epoch:?\[(\d+)\],?\s*Accuracy:?\s*([\d.]+)%,?\s*Loss:?\s*([\d.]+)"
    matches = re.findall(pattern, content)
    
    for m in matches:
        epochs.append(int(m[0]))
        accs.append(float(m[1]))
        losses.append(float(m[2]))

    plt.figure(figsize=(12, 5))
    
    plt.subplot(1, 2, 1)
    plt.plot(epochs, accs, label='Training Accuracy', color='#1f77b4', linewidth=2)
    plt.title(f'{exp_name}: Accuracy Curve')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy (%)')
    
    plt.xlim(0, 80)
    plt.ylim(0, 100)
    
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, losses, label='Training Loss', color='#d62728', linewidth=2)
    plt.title(f'{exp_name}: Loss Curve')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    
    plt.xlim(0, 80)
    plt.ylim(0, 2.5) 
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.legend()

    plt.tight_layout()
    plt.savefig(f'{exp_name}_standardized_curves.png', dpi=300) 
    plt.show()

plot_from_log('01_baseline_architecture_log.txt', '01_baseline_architecture')
